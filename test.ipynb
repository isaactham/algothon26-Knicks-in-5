# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('prices.txt', sep=r'\s+', header=0)
df.head()  #taking a look at the shape of the data


#taking a look at one stock just to get a feel of it
instrument = df[df.columns[0]] 

plt.figure(figsize=(10, 4))
plt.plot(instrument)
plt.title('Price')
plt.show()
